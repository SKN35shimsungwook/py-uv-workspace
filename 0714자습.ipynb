# %%
삼성 = Stock("삼성전자", "005930")

class Stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

print(삼성.name)
print(삼성.code)
# Out:
# 삼성전자
# 005930

# %%
class Stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code
        
삼성 = Stock("삼성전자", "005930")
print(삼성.name)
print(삼성.code)
# Out:
# 삼성전자
# 005930

# %%
class Human:
    pass

# %%
class Stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):

        self.name =  name
    
    def set_code(self, code):
        self.code = code
    


    a = Stock(None, None)
    a.set_name("삼성전자")
    a.set_code('005930')
    print(a.name)
    print(a.code)
# Out:
# 삼성전자
# 005930
