# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다."도둑이야"')
# Out:
# 신씨가 소리질렀다."도둑이야"

# %%
pwd
# Out:
# 'c:\\sk-encore\\py-uv-workspace'

# %%
print("c:\Windows")
# Out:
# c:\Windows
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\playdata2\AppData\Local\Temp\ipykernel_2588\2712340212.py:1: SyntaxWarning: invalid escape sequence '\W'
#   print("c:\Windows")

# %% [markdown]
# 5.\t는 모륵겠고 \n은 줄바꿈

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %% [markdown]
# "오늘은" "일요일"

# %%
print ("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print('naver;kakao;sk;samsung')
# Out:
# naver;kakao;sk;samsung

# %%
print('naver/kakao/sk/samsung')
# Out:
# naver/kakao/sk/samsung

# %%
print("first");print("second")
# Out:
# first
# second

# %%
print(end="first");print(end="second")
# Out:
# firstsecond

# %%
print("first", end="");print("second")
# Out:
# firstsecond

# %%
print(5%3)
# Out:
# 2

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
삼성전자 = 50000
총평가금액 = 삼성전자*10
print(총평가금액)
# Out:
# 500000

# %%
시가총액 = '298조'
현재가 = 50000
per= 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(per, type(per))
# Out:
# 298조 <class 'str'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s = "hello"
t = "python"
print(s+ '!',t)
# Out:
# hello! python

# %%
print(2+2*3)
# Out:
# 8

# %%
a = 128
print (type(a))
# Out:
# <class 'int'>

# %%
a = 132
print(type(a))
# Out:
# <class 'int'>

# %%
num_str = "720"

# %%
a = num_str
print(a)
# Out:
# 720

# %%
num_str = "720"  #형변환
num_int = int(num_str)
print(num_int+1, type(num_int))
# Out:
# 721 <class 'int'>

# %%
num_str = "250"
num_int = int(num_str)
print("제나이는", num_str, "살입니다")
# Out:
# 제나이는 250 살입니다

# %% [markdown]
# 정수 99를 문자열로 변환해서, "현재 점수는 " + 그값 + "점입니다"를 출력하세요.

# %%
num_int = "99"
num_str = int(num_int)
print("현재 점수는", num_str, "점입니다.")
# Out:
# 현재 점수는 99 점입니다.

# %%
num_int = 99
num_str = str(num_int)
print("현재 점수는", num_str, "점입니다.")
# Out:
# 현재 점수는 99 점입니다.

# %% [markdown]
# 정수 15로 시작하는 변수(age)를 만들고, 이를 문자열로 변환한 새 변수(age_str)를 만들어서, "제 나이는 " + age_str + "살입니다"를 출력하세요.

# %%
num_int = 15
num_str = str(num_int)
print("제 나이는", num_str,"살입니다.")
# Out:
# 제 나이는 15 살입니다.

# %%
num_int = 100
num_str = str(num_int)
print(num_str)
print(type(num_str))
# Out:
# 100
# <class 'str'>

# %%
num_str = "15.79"
num_int = int(num_str)
print(num_int)
print(type(num_int))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 num_str = "15.79"
# ----> 2 num_int = int(num_str)
#       3 print(num_int)
#       4 print(type(num_int))
#
# ValueError: invalid literal for int() with base 10: '15.79'

# %%
int("15")
str(15)
float("15.79")
# Out:
# 15.79

# %%
float("15.79")
# Out:
# 15.79

# %% [markdown]
# 문자열 "3.14"를 실수로 변환하세요.
#
# 정수 7을 실수로 변환하세요.
#
# 실수 9.99를 정수로 변환하세요. (힌트: 이땐 소수점 이하가 어떻게 될지도 생각해보세요)

# %%
float("3.14")
float(7)
int(9.99)
# Out:
# 9

# %%
result = float("3.14")
print(result)
print(type(result))
# Out:
# 3.14
# <class 'float'>

# %%
result = float("15.79")

print(result)
print(type(result))
# Out:
# 15.79
# <class 'float'>

# %%
year = {"2020", "2026", "2025", "2024"}
a = float(year)
print(a)
print(type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 year = {"2020", "2026", "2025", "2024"}
# ----> 2 a = float(year)
#       3 print(a)
#       4 print(type(a))
#
# TypeError: float() argument must be a string or a real number, not 'set'

# %%
year = "2020"
int_year = int(year)

print(int_year)
print(int_year+6)
print(int_year+5)
print(int_year+4)
# Out:
# 2020
# 2026
# 2025
# 2024

# %%
birth_year = "1995"
int_birth_year = int('1995')
print(int_birth_year+30)
# Out:
# 2025

# %% [markdown]
# [연습문제 1] 마트 할인율 계산하기 (난이도: ★☆☆)
# 상황: 마트에서 원래 20000원짜리 고기를 세일하고 있습니다.
# price = "20000" 이라는 변수가 주어졌습니다.
# 세일 가격은 원래 가격에서 3000원을 빼야 합니다.
#
# 질문 1: 문자열 "20000"을 계산할 수 있는 숫자로 만들려면 int()와 float() 중 무엇을 써야 할까요?
#
# 질문 2: 변환된 값에서 3000원을 뺀 세일 가격을 출력하는 계산식을 말로 설명해 주세요.

# %%
price = "20000"
int_price = int(price)
print(int_price -3000)
# Out:
# 17000

# %% [markdown]
# [연습문제 2] 피자 한 판 칼로리 계산 (난이도: ★★☆)
# 상황: 피자 한 조각의 칼로리가 350.5칼로리입니다.
# pizza_piece = "350.5" 라는 변수가 주어졌습니다.
# 피자 3조각을 먹었을 때의 전체 칼로리를 구하고 싶습니다.
#
# 질문 1: 문자열 "350.5"를 숫자로 만들려면 int()와 float() 중 무엇을 써야 할까요? (힌트: 소수점이 들어있어요!)
#
# 질문 2: 변환된 값을 활용해서 3조각의 전체 칼로리를 구하려면 어떤 산수 계산식(+, -, *, /)을 써야 할까요?

# %%
pizza_piece = ("350.5")
float_pizza_piece =  float(pizza_piece)
print(float_pizza_piece * 3)
# Out:
# 1051.5

# %% [markdown]
# 상황:
# 내 통장 잔액: my_money = "50000"
# 친구에게 돌려받은 돈: received = "15000"
#
# 미션: 두 개의 문자열 변수("50000", "15000")를 각각 알맞은 숫자 타입으로 형변환한 뒤, 최종 잔액(원래 잔액 + 돌려받은 돈)을 계산하여 출력하는 코드를 완성해 보세요.
#
# 실행하기 전, 변수 이름에 오타가 없는지 눈으로 3초간 체크해보는 것 잊지 마시고요! 편하게 코드를 작성해서 올려주세요.

# %%
my_money = "50000"
received = "15000"

a = int(my_money)
b = int(received)

print(a+b)
# Out:
# 65000

# %%
int_aircon = 48584

print(int_aircon * 36)
# Out:
# 1749024

# %%
letters = 'python'
print(letters.split(0:3))
# Out:
#   Cell In[85], line 2
#     print(letters.split(0:3))
#                          ^
# SyntaxError: invalid syntax

# %%
letters = 'python'
print(letters[0],letters[2])
# Out:
# p t

# %%
license_plate = "24가 2210"
car = license_plate
print(car[3:8])
# Out:
#  2210

# %%
header = ['학번','이름','전공']
students = [
    ['202601', '홍길동', '컴퓨터공학'],
    ['202602', '이순신', '데이터사이언스'],
    ['202603', '유관순', '인공지능학']
]

data = [dict(zip(header, student)) for student in students]
print(data)
# Out:
# [{'학번': '202601', '이름': '홍길동', '전공': '컴퓨터공학'}, {'학번': '202602', '이름': '이순신', '전공': '데이터사이언스'}, {'학번': '202603', '이름': '유관순', '전공': '인공지능학'}]

# %% [markdown]
# 3. 내 것으로 만드는 3초 확인 연습 (말로만 답해보기)
# 음수 인덱싱(-)의 감을 완전히 잡기 위해, 아래 질문에 말로만 가볍게 답해 보세요!
#
# 상황: 전화번호 변수 phone = "010-1234-5678" 이 주어졌습니다.
# 맨 뒤의 **네 자리 숫자("5678")**만 음수 인덱싱을 활용해서 쏙 뽑아내고 싶습니다.
#
# 질문: print(phone[ ? : ]) 에서 물음표 ?에 들어갈 숫자는 마이너스 몇 번일까요? 뒤에서부터 세어보세요!

# %%
phone = "010-1234-5678"
print(phone[-4:])
# Out:
# 5678

# %%
string = "홀짝홀짝홀짝"
print(index.string"홀")
# Out:
#   Cell In[101], line 2
#     print(index.string"홀"):
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
