# %%
import this

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(len(keyword.kwlist))
# Out:
# 35

# %%
a = 10
print(dir(a))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %%
# python version 확인
# !python --version
# Out:
# Python 3.12.13

# %%
# %pwd
# Out:
# 'c:\\sk-encoa\\py-uv-workspace'

# %%
print(10) ; print('Hellow Python')
# Out:
# 10
# Hellow Python

# %%
# 내장함수는 식별자로 사용할 수 있다.
# 그러나 원래의 기능은 잃어버린다.
list = [1,3,5]
print(list)

# list함수의 기능을 원상복귀하기 위해서 del키워드를 사용하면 된다.
del list


print(list())
# Out:
# [1, 3, 5]
# []

# %%
b = [1,2,3]
print(sum(b))

sum = 0
sum = sum + b[0] +b[1] +b[2]
# 오류는 아니지만 원하는 결과가 아니다 sum이 예약어로만 작동했기에
# Out:
# 6

# %%
# 변수(variable) : 값을 저장하기 위 메모리 공간
# start = 1
# end = 1

start = end = 1

# %%
# ''로 감싸놓으면 문자로 인식 --> +는 문자열 연결로 사용됨
a = '3' + '4'
# +가 산술연산자로 사용됨
b = 3 + 4
print(a)
print(b)
# Out:
# 34
# 7

# %%
#java, c 경우
# int num = 3

# python, javascript 경우
num = 10
num = 'python'

# %% [markdown]
# # 자료형
#
#
# 1. 데이터 저장방법에 따른 자료형의 분류
#   직접(direct)형 : 직접 데이터를 표현하는 자료형 : int, float, complex
#   시퀀스(sequence)형: 다른 데이터를 포함하는 자료형, 순서가 있는 집합 자료형 : list,str, tuple, bytes, bytearray,range
#   매핑(Mapping)형 : 다른 데이터를 포함하는 자료형 : dict
#   집합(Set)형 : 순서가 없고, 중복된 값도 없다. : set, frozenset
#
#
# 2. 변경 가능성에 따른 자료형 분류
#   변경 가능형(Mutable) : 데이터의 값을 변경할 수 있다.  : list, dict, set
#   변경 불가능형(Immutable) : 데이터의 값을 변경할 수 없다. : int, float, complex, str, tuple, frozenset
#
#
# 3. 데이터 저장 개수에 따른 자료형의 분류
#   리터널(Literal/Scalar)형 : 한 가지 객체만 저장한다. : int, bytes, str, float, complex
#   컨테이너(Container)형 : 여러 가지 객체를 저장한다. : list, tuple, dict, set, fronzenset

# %% [markdown]
# type():데이터 자료형 확인

# %%
type(5)
# Out:
# int

# %%
type(85.3)
# Out:
# float

# %%
type([1,3,5])
# Out:
# list

# %%
type((1,3,5))
# Out:
# tuple

# %%
def call():
    return 2

# %%
type(call)
# Out:
# function

# %%
type({'a':3, 'b':4})
# Out:
# dict

# %% [markdown]
# dir() : 객체의 자원을 검색할 수 있다.

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
a = [1,2,3]
print(dir(a))
print(a.__dir__())
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ['__new__', '__repr__', '__hash__', '__getattribute__', '__lt__', '__le__', '__eq__', '__ne__', '__gt__', '__ge__', '__iter__', '__init__', '__len__', '__getitem__', '__setitem__', '__delitem__', '__add__', '__mul__', '__rmul__', '__contains__', '__iadd__', '__imul__', '__reversed__', '__sizeof__', 'clear', 'copy', 'append', 'insert', 'extend', 'pop', 'remove', 'index', 'count', 'reverse', 'sort', '__class_getitem__', '__doc__', '__str__', '__setattr__', '__delattr__', '__reduce_ex__', '__reduce__', '__getstate__', '__subclasshook__', '__init_subclass__', '__format__', '__dir__', '__class__']

# %% [markdown]
# help() : 자료형에서 제공하는 메소드 사용법을 검색할 수 있다.

# %%
#print(help(str))
print(help(str.index))
# Out:
# Help on method_descriptor:
#
# index(...) unbound builtins.str method
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.
#
# None

# %%
'hello'.index('h')
# Out:
# 0

# %% [markdown]
# ## Sequence 자료형
# - Sequence은 여러 객체를 저장할 수 있는 순서를 갖는 연속된 자료형이다.
# - 자료형 종류 : str, tuple, list
# - sequence형의 공통적인 연산
#   - 인덱싱(indexing) - 선택연산
#   - 슬라이싱(slicing) - 범위선택연산
#   - 연결하기
#   - 반복하기
#   - 멤버 검사
#   - 길이정보

# %% [markdown]
# 문자열(str)
#
#
# 문자열은 문자들을 표현하는 자료형으로 작은따옴표(')나 큰따옴표(")로 묶는다.
# 문자열의 슬라이싱 : [인덱스 시작 : 인덱스 끝 : 스텝]
# 스텝의 default은 1의 값을 갖는다.

# %%
a = 'Life is too short, You need python'
print(a)

a = "Life is too short, You need python"
print(a)
# Out:
# Life is too short, You need python
# Life is too short, You need python

# %%
a = "Python's favorite food is perl"
print(a)

a = 'Python\'s favorite food is perl'
print(a)

a = '\"Python\'s favorite food is perl\"'
print(a)
# Out:
# Python's favorite food is perl
# Python's favorite food is perl
# "Python's favorite food is perl"

# %%
b = """
    Life is too short,
    You need python
"""
print(b)
# Out:
#     Life is too short,
#     You need python

# %%
#문자열 길이
print(len(b))
# Out:
# 44

# %%
#indexing(인덱싱)
s_val = 'hello python'
print(s_val[0])
# Out:
# h

# %%
#slicing(슬라이싱) [start:end:step] end,step의 경우 생략 가능 :는 필수
print(s_val[1:3]) #1이상 3미만
# Out:
# el

# %%
print(s_val[0:]) #0부터 끝까지
print(s_val[:])
# Out:
# hello python
# hello python

# %%
s_val = 'hello python'
print(s_val[-1])
# Out:
# n

# %%
print(s_val[-3:-1])
# Out:
# ho

# %%
print(s_val[-1:-3:-1])
# Out:
# no

# %%
s_val + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 s_val + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
s_val * 2
# Out:
# 'hello pythonhello python'

# %% [markdown]
# 문자열 반복하기 (*)연산자를 사용

# %%
s_val * s_val
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 s_val * s_val
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s_val = 'hello python!' 
s_val = 'H' + s_val[1:]
print(s_val)
# Out:
# Hello python!

# %% [markdown]
# 문자열을 변경할 때 슬라이싱과 연결하여 사용

# %% [markdown]
# in 연산자로 멤버검사를 해서 부분 문자열의 존재 확인

# %%
s_val = 'red green blue'
print(s_val)
# Out:
# red green blue

# %%
# s_val 변수에 green이 있니?
'green' in s_val
# Out:
# True

# %%
# s_val 변수에 white가 있니?
'white' in s_val
# Out:
# False

# %% [markdown]
# 문자열 포매팅(서식지정) : 어떤 문서 양식을 만들어 넣고 빈칸에 필요한 내용을 채워서 문서를 지정한다.
#
#
# 문자열포매팅(서식지정) 형식
#
#
# |코드|설명 |
# |---|:---:|
# |%d|정수|
# |%f|실수|
# |%s|문자열|
# |%c|하나의문자|
# |%o|8진수|
# |%x|16진수|
# |%%|%기호자체를출력하고자할때|

# %%
s_val7 = 'python'
s_val8 = 83.5


print('%s 의 점수는 %.1f입니다.' % ( s_val7, s_val8)) # python1, 2방식
print('{} 의 점수는 {}입니다.'.format(s_val7, s_val8)) # python3 방식
print('{1} 의 점수는 {0}입니다.'.format(s_val8, s_val7))
print('{subject} 의 점수는 {jumsu}입니다.'.format(jumsu=s_val8, subject=s_val7))
print('{{0}} 의 점수는 {{1}}입니다.'.format(s_val7, s_val8)) # { }자체를 출력할때 {{}}을 한다.
print('{{{0}}} 의 점수는 {{{1}}}입니다.'.format(s_val7, s_val8)) # {}자체와 값을 출력할때는 {{{}}}을 한다.


print('{0:<10} 의 점수는 {1}입니다.'.format(s_val7, s_val8))  # 10자리 확보하고 남은 공간은 오른쪽을 여백으로 채운다.
#print('{:<10} 의 점수는 {}입니다.'.format(s_val7, s_val8))


print('{0:>10} 의 점수는 {1}입니다.'.format(s_val7, s_val8))
# Out:
# python 의 점수는 83.5입니다.
# python 의 점수는 83.5입니다.
# python 의 점수는 83.5입니다.
# python 의 점수는 83.5입니다.
# {0} 의 점수는 {1}입니다.
# {python} 의 점수는 {83.5}입니다.
# python     의 점수는 83.5입니다.
#     python 의 점수는 83.5입니다.

# %% [markdown]
# 문자열에서 제공하는 메소드

# %%
a = 'hobby'
print(a.count('b')) # 'b' 문자개수 리턴
# Out:
# 2

# %%
print(a.find('b'))
print(a.index('b'))
# Out:
# 2
# 2

# %%
print(a.find('c')) # 찾는 문자열이 없으면 -1을 리턴
print(a.index('c')) # 찾는 문자열이 없으면 오류 발생 ValueError: substring not found
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 2
#       1 print(a.find('c')) # 찾는 문자열이 없으면 -1을 리턴
# ----> 2 print(a.index('c')) # 찾는 문자열이 없으면 오류 발생 ValueError: substring not found
#
# ValueError: substring not found

# %%
# 'apple'문자열의 각각의 문자 사이에 '*'를 삽입
'*'.join('apple')
# Out:
# 'a*p*p*l*e'

# %%
'*'.join(['red','green','blue'])
# Out:
# 'red*green*blue'

# %%
a = 'hello'
print(a.upper())
# Out:
# HELLO

# %%
a = 'HELLO'
print(a.lower())
# Out:
# hello

# %%
a = ' hello word  '
print(len(a))

print(a.lstrip())         # 왼쪽 공백 제거
print(len(a.lstrip()))

print(a.rstrip())         # 오른쪽 공백 제거
print(len(a.rstrip()))

print(a.strip())          # 양쪽 공백 제거
print(len(a.strip()))
# Out:
# 13
# hello word
# 12
#  hello word
# 11
# hello word
# 10

# %%
a = 'Hello Python'
b = a.replace('Python','파이썬') # 문자열 변경
print(b)
print(a)
# Out:
# Hello 파이썬
# Hello Python

# %%
a = 'Red Green Blue'
print(a.split()) # 공백을 기준으로 분리

a = 'Red*Green*Blue'
print(a.split('*'))
# Out:
# ['Red', 'Green', 'Blue']
# ['Red', 'Green', 'Blue']

# %%
a = 'Red Green Blue'
print(a.split()) 

a = 'Red*Green*Blue'
print(a.split('*'))
      
import re
a = 'Red**Green*Blue'         # *가 랜덤한 개수로 있을 때
print(re.split(r'\*+',a))
# Out:
# ['Red', 'Green', 'Blue']
# ['Red', 'Green', 'Blue']
# ['Red', 'Green', 'Blue']

# %% [markdown]
# 리스트(list)
#  - 시퀀스(sequence) 자료형으로 데이터 크기나 원소값을 변경할 수 있다.
#  - 리스트는 [ ]대괄호로 표현한다.

# %%
a = list()
print(a)
print(type(a))
print(dir(a))
# Out:
# []
# <class 'list'>
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
a = [ 10 , 20 , 30]
print(a)
# Out:
# [10, 20, 30]

# %%
a[0] # indexing
# Out:
# 10

# %%
print(a[0:]) # slicing
print(a[:])
# Out:
# [10, 20, 30]
# [10, 20, 30]

# %%
print(a[:-1]) # 10 20 30 이 각각 양의 방향으로 0,1,2 음의 방향으로 -3,-2,-1과 매칭되어 [0:-1]로 0이상 -1 미만이므로 10과 20만 print 된다
print(a[0:-1])
# Out:
# [10, 20]
# [10, 20]

# %% [markdown]
# list는 다양한 타입을 함께 포함할 수 있다. (hetergeneous)

# %%
a = [10 , 'pythoon' , 80.5 , True]
print(a)
# Out:
# [10, 'pythoon', 80.5, True]

# %%
a = [[ 10 , 20 ] , { 100, 200 } ,(1,3), {'x':5, 'y':8}]
print(a)
# Out:
# [[10, 20], {200, 100}, (1, 3), {'x': 5, 'y': 8}]

# %% [markdown]
# list는 (+) 연산자를 사용하여 연결하기를 할 수 있다.

# %%
a = [1,2]
a + a
# Out:
# [1, 2, 1, 2]

# %% [markdown]
# list는 (*) 연산자를 사용하여 연결하기를 할 수 있다.

# %%
a * 2
# Out:
# [1, 2, 1, 2]

# %% [markdown]
# list는 mutable 이므로 요소들을 변경할 수 있다.

# %%
a = ['apple' , 'banana' , 100 , 200 ]
print(a)

#a[0] = 1  # a[0]에 1로 변경
#a[1] = 2
a[0:2] = 1,2  # 좌변과 우변의 갯수가 같으면 괄호를 무엇으로 하든 상관없다
print(a)
# Out:
# ['apple', 'banana', 100, 200]
# [1, 2, 100, 200]

# %%
a = ['apple' , 'banana' , 100 , 200 ]
print(a)

a[0:2] = [50]  # 좌우변의 갯수가 다를시 괄호의 종류가 중요
print(a)
# Out:
# ['apple', 'banana', 100, 200]
# [50, 100, 200]

# %%
a = ['apple' , 'banana' , 100 , 200 ]
a[0:1] = [300,400,500]
print(a)
# Out:
# [300, 400, 500, 'banana', 100, 200]

# %% [markdown]
# list의 일부 요소를 삭제 할 수 있다. 단 추가나 삭제는 indexing이 아니라 slicing을 할 것!

# %%
a = ['apple' , 'banana' , 100 , 200 ]
a[0:1] = []
print(a)
# Out:
# ['banana', 100, 200]

# %% [markdown]
# list에서 확장슬라이싱을 사용할때는 왼쪽과 오른쪽 요소 갯수가 같아야 한다.(step값을 적용할 경우 갯수가 다르면 문제가 생긴다. step = 1 이면 괜춘)

# %%
a = [2, 4, 6, 8]
print(a)

a[:] = [-1, -2, -3, -4]
print(a)

a = [2, 4, 6, 8]
a[::2] = [-1, -2, -3, -4, -5]
print(a)
# Out:
# [2, 4, 6, 8]
# [-1, -2, -3, -4]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 8
#       4 a[:] = [-1, -2, -3, -4]
#       5 print(a)
#       6
#       7 a = [2, 4, 6, 8]
# ----> 8 a[::2] = [-1, -2, -3, -4, -5]
#       9 print(a)
#
# ValueError: attempt to assign sequence of size 5 to extended slice of size 2

# %%
a = [2, 4, 6, 8]
a[::-1] = [-1, -2, -3, -4]
print(a)


# ValueError: attempt to assign sequence of size 5 to extended slice of size 4
a = [2, 4, 6, 8]
a[::-1] = [-1, -2, -3, -4, -5]
print(a)
# Out:
# [-4, -3, -2, -1]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 6
#       2 a[::-1] = [-1, -2, -3, -4]
#       3 print(a)
#       4
#       5 a = [2, 4, 6, 8]
# ----> 6 a[::-1] = [-1, -2, -3, -4, -5]
#       7 print(a)
#
# ValueError: attempt to assign sequence of size 5 to extended slice of size 4

# %% [markdown]
# list는 한 변수에서 데이터를 각각 꺼내는 언팩킹(unpacking) 지원을 한다.

# %%
fruits = ['apple', 'mango', 'grape', 'banana']
print(fruits)

zero, one, two, three = fruits
print(zero, one, two, three)

zero,one,_,_ = fruits
print(zero, one)

zero, *group = fruits
print(zero, group)
print(type(zero), type(group))

# *는 한번만 사용해야 한다.
# zero, *group1, *group2 = fruits
# print(zero, group)

*group, zero = fruits
print(group, zero) # ['apple','mango','grape'] banana

zero, *group, three = fruits
print(zero, *group, three)
# Out:
# ['apple', 'mango', 'grape', 'banana']
# apple mango grape banana
# apple mango
# apple ['mango', 'grape', 'banana']
# <class 'str'> <class 'list'>
# ['apple', 'mango', 'grape'] banana
# apple mango grape banana

# %% [markdown]
# Tuple(튜플)
#  - 변경이 불가능(immutable)한 순서(sequence)가 있는 자료형이다.
#  - 튜플은 ( ) 소괄호로 표시한다.

# %%
t = ()
print(t,type(t))
print(dir(t))
# Out:
# () <class 'tuple'>
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
t = (1,2,3)
print(t,type(t))
# Out:
# (1, 2, 3) <class 'tuple'>

# %%
t = 1,2,3          # tuple은 ( ) 소괄호를 생략할 수 있다.
print(t,type(t))
# Out:
# (1, 2, 3) <class 'tuple'>

# %%
#  t =(2)      int로 처리된다
t = (2,)      # tuple로 처리된다  t = 2, 도 tuple로 활용된다.
print(t,type(t))
# Out:
# (2,) <class 'tuple'>

# %%
t = (2,(10,20))
